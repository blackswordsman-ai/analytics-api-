# %%
import requests


#GET api/events
path="/api/events/"
base_url = "http://localhost:8000"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"page":"/test", "description":"abc123"})
print(response.headers)
print('ok',response.ok)
if response.ok:
    data = response.json()
    print(data, type(data),data.get('items'))
else:
  print(response.text)
# Out:
# {'date': 'Mon, 23 Feb 2026 17:18:43 GMT', 'server': 'uvicorn', 'content-length': '42', 'content-type': 'application/json'}
# ok True
# {'id': 123, 'page': '/test', 'description': ''} <class 'dict'> None
